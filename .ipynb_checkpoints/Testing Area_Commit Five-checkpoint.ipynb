# %%
# Imported libraries
import pydicom
import matplotlib.pyplot as plt
import numpy as np
import sys
import matplotlib as mpl
import imageio
import cv2
import sys
import os
import random
import pickle

# %%
# Problem Log
"""
    
    Retreiving files of the original patient scans for designated scan
    Problems occured:
    1- Not all patient directories have single scan history
    Patients with such issue are: 06-0138, 19-5960.
    Resolved by validating ID for every scan
    Status: Resolved by defining an aiding module 'multipleVisits' that operates in the else statement
    
    if(one visit)-> undergo the process of retreiving patient scans images
    else -> use the 'multipleVisits' module to identify the visit date containing scans
            segmented followed by retreiving patient data
                
    Another problem to be handled
    2- Second problem is the sorting of the original scans dicom files.
    The files are named 0000-0023. However they aren't aligned in order through
    that naming, instead there is a dicom object attribute called
    InstanceNumber that identifies the order of the scans.
    Status: An aiding function 'dicomSort' was declared to handle this issue.
                
    
    A third problem occured
    3- Some of the original scans aren't of the usual dimensions (256,256)
    but rather (512,512). Problem discovered at
    Patient: TCGA-06-0138
    Visit Date: 11-25-2002-91840
    Scan: 10-AX T1 POST GD FLAIR-87338
    Dicom: 000000.dcm
    UNKNOWN IF SAME ISSUE OCCURS AT OTHER PLACES ALTHOUGH ITS LIKELY FOR THE SAME PATIENT
    
    Problem discovered when storing the original scan arrays in an already
    initialized original_scans npArray of zeroes that was initialized with
    the dimensions (256,256)
    --------------------------------------------------------------------------
    Status: Trying out the helper function imageArray to dynamically handle different
    dimensions of differernt dicom files
                
    
    """
"----------------------------------------"
# Out:
# '----------------------------------------'

# %%
# Place directory paths and declare needed
# variables for initiating the general categorization
# and storing of patient scans arrays

original_directory_path = '/media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/'
segmented_directory_path = '/home/omar/Desktop/DropboxData/Dropbox-GBM/TCGA-GBM/'
result_directory_path = '/home/omar/Desktop/TrainingResultTEST/'
patients = []

"""

Patient pickle file structure
File Name: Patient ID (TCGA-xx-xxxx)
DATA:
[
    [sorted original 23 arrays of AX T2],
    [sorted original 23 arrays of AX T1],
    [sorted original 23 arrays of FLAIR],
    [sorted original 23 arrays of POST],
    [segmentation array]

]

"""


# Get all the patient IDs that will be used for the training phase and sort them
for patient in os.listdir(segmented_directory_path):
    patients.append(patient)
patients.sort()
# We now have a list of all the patients needed for the training phase
# print (patients)

# %%
# Aiding modules and functions
"""
    Module to handle the existence of subfolders for multiple patient visits
    Purpose and working principle:
    Iterates over the original patient subfolders till it finds scan folders relevant by scan ID
    Inputs are, patient ID and an array containing
    the segmentation filenames in the form 'seg_corrected_AX-*****.dcm'
    Returns the subfolders containing the relevant original scans (usually one folder)"""

def multipleVisits(patient_id, segmented_scans):
    subfolders = os.listdir(original_directory_path+patient_id)
    segmented_ids = []
    for i in segmented_scans:
        segmented_ids.append(i[-9:-4])
    target_folders = []
    for folder in subfolders:
        images_folder = os.listdir(original_directory_path+patient_id+"/"+folder)
        for scans in images_folder:
            if scans[-5:] in segmented_ids and folder not in target_folders:
                target_folders.append(folder)
    return target_folders

"""
    Module to handle the issue with sorting of the original dicom files of the
    patient because the filenames are in no way sorted either. The working principle
    of the function is that it takes in an array of filenames and returns a dictionary
    where key is the instance number and the value is the correspondent file name.
    The keys are sorted to make the appending the original patient data in the pickle 
    file be in the correct order
"""

def dicomSort(path_to_scans, file_array):
    dicom_sorting = {}
    for file in range(len(file_array)):
        instance = pydicom.dcmread(path_to_scans + "/" + file_array[file])
        instance_value = instance.InstanceNumber
        dicom_sorting[instance_value] = file_array[file]
    sorted(dicom_sorting.keys())
    return dicom_sorting


"""
    Introducting the third helper function to handle each image with its respective size
    to parse it into numpyArray structure in a generalized form, takes the path to 
    scans and along with it the desired dicom file to return the final numpyArray
"""
def imageArray(path_to_visit, scans_folder):
    path_of_scans = path_to_visit + "/" + scans_folder
    files = os.listdir(path_of_scans)
    imagesDict = dicomSort(path_of_scans, files)
    """
    
    Since all the dicom files in any directory have the same shape
    (from observing the faulty patient logs) we need to grab any random
    dicom file to get the dimensions of the array and be able to initialize
    the size and dimensions of that scan array
    
    """
    value = list(imagesDict)[0]
    
    randImageData = pydicom.dcmread(path_of_scans+"/"+imagesDict[value]).pixel_array
    dimensions = randImageData.shape
    sizeOfArray = (len(imagesDict), dimensions[0],dimensions[1])
#     print ((dimensions[0],dimensions[1], len(imagesDict)))
    image_array = np.zeros(sizeOfArray)
    
    for image in sorted(imagesDict.keys()):
        ds = pydicom.dcmread(path_of_scans+"/"+imagesDict[image])
        print(len(image_array), image, imagesDict[image], ds.pixel_array.shape, path_of_scans)
        image_array[image-1] = ds.pixel_array
    
    return image_array

# %%
"""

After having the training patients recognized, we now need to start
creating pickle files for every patient to store the data at

Pickle file Information
Name: Patient
Data included:
a. original scan images
b. arrays for each of the segmented scans

"""
faulty_patient_data = []

for patient_id in patients:
#     Getting the corrected segmented scan filenames for every patient (ID at indexing -9:-4)
    patient_segmented_files = []
    for scan in os.listdir(segmented_directory_path+patient_id+'/DSO/'):
        if "corrected" in scan:
            patient_segmented_files.append(scan)
#     Pickle file for patient initialized
    pickleFile = open("%s.pickle" % (patient_id) ,"wb")
#     Data Array for patient initialized
    data_array = []
    segmented_ids = []
    for dcm in patient_segmented_files:
        segmented_ids.append(dcm[-9:-4])

    
    if(len(os.listdir(original_directory_path+patient_id)) == 1):
#         If only one visit for the patient
        visit_date = os.listdir(original_directory_path+patient_id)[0]
        path_to_visit = original_directory_path + patient_id + '/' + visit_date
        for scan_directory in os.listdir(original_directory_path+patient_id+"/"+visit_date):
#             Scan directory is the level in which scan type folders of that visit is reached
            if scan_directory[-5:] in segmented_ids:
                folder_containing_scans = scan_directory
                array_of_patient_scans = imageArray(path_to_visit, folder_containing_scans)
                data_array.append(array_of_patient_scans)
        pickle.dump(data_array, pickleFile)
        pickleFile.close()
#     In case of having multiple visits by the patient
    else:
        folder_containing_scans = multipleVisits(patient_id, patient_segmented_files)
        for folder in folder_containing_scans:
            visit_date = folder
            for scan_directory in os.listdir(original_directory_path+patient_id+"/"+visit_date):
                if scan_directory[-5:] in segmented_ids:
                    folder_containing_scans = scan_directory
                    path_to_visit = original_directory_path+patient_id+"/"+visit_date
                    array_of_patient_scans = imageArray(path_to_visit, folder_containing_scans)
                    data_array.append(array_of_patient_scans)
        pickle.dump(data_array,pickleFile)
        pickleFile.close()
# Out:
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/3-AX T2 FSE-27597
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/4-AX FLAIR-23922
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/5-AX T1-62419
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0006/08-23-1996-MRI BRAIN W WO CONTRAMR-42545/6-AX T1 POST-26504
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/3-AX T2 FSE-01423
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/4-AX FLAIR-31290
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/5-AX T1-38458
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0009/06-14-1997-MRI BRAIN WWO CONTRAMR-13452/6-AX T1 POST-70502
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/3-AX T2 FSE-71371
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/4-AX FLAIR-45181
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/5-AX T1-73320
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0046/11-28-1998-MRI BRAIN WWO CONTR-34177/6-AX T1 POST-76642
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/4-AX T2 FSE-25529
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 4 000007.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 5 000015.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 6 000009.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 7 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 8 000008.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 9 000011.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 10 000003.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 11 000013.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 12 000021.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 13 000014.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 14 000002.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 15 000006.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 16 000020.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 17 000012.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 18 000010.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 19 000017.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 20 000005.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 22 000016.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 23 000022.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/5-AX FLAIR-89982
# 23 1 000004.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/6-AX T1-67057
# 23 2 000019.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/6-AX T1-67057
# 23 3 000018.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-02-0054/05-16-1999-MRI BRAIN WWO CONTR-68633/6-AX T1-67057
# ...
# 34 1 000031.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 2 000026.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 3 000012.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 4 000017.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 5 000011.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 6 000014.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 7 000015.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 8 000018.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 9 000020.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 10 000000.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 11 000013.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 12 000010.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 13 000004.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 14 000001.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 15 000007.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 16 000003.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 17 000021.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 18 000009.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 19 000022.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 20 000025.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 21 000024.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 22 000016.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 23 000008.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 24 000002.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 25 000006.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 26 000019.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 27 000023.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 28 000030.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 29 000033.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 30 000028.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 31 000032.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 32 000029.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 33 000027.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 34 000005.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/7-FLAIR AX-90386
# 34 1 000001.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 2 000021.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 3 000018.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 4 000015.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 5 000003.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 6 000009.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 7 000005.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 8 000022.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 9 000006.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 10 000007.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 11 000011.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 12 000020.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 13 000004.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 14 000008.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 15 000013.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 16 000000.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 17 000002.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 18 000012.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 19 000023.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 20 000016.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 21 000014.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 22 000010.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 23 000019.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 24 000017.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 25 000024.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 26 000029.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 27 000031.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 28 000027.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 29 000025.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 30 000030.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 31 000033.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 32 000032.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 33 000026.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 34 000028.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/8-TIR T1 AX-02076
# 34 1 000028.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 2 000026.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 3 000002.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 4 000006.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 5 000001.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 6 000008.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 7 000000.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 8 000021.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 9 000007.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 10 000009.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 11 000005.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 12 000015.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 13 000004.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 14 000016.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 15 000019.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 16 000003.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 17 000022.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 18 000013.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 19 000020.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 20 000011.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 21 000018.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 22 000014.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 23 000017.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 24 000023.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 25 000012.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 26 000010.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 27 000024.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 28 000029.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 29 000032.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 30 000030.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 31 000033.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 32 000027.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 33 000025.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 34 34 000031.dcm (256, 208) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-19-5960/03-15-2004-NR MRI BRAIN WWO-30388/9-T1 AXIAL Gd-31768
# 20 20 000000.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-76-4932/03-16-1997-MRI BRAIN STRYKER-44803/3-BRAINSTRYKERT1AXIAL-83401
# 20 21 000001.dcm (256, 256) /media/omar/New Volume/TCIA Data/GBM/Data/TCGA-GBM/TCGA-76-4932/03-16-1997-MRI BRAIN STRYKER-44803/3-BRAINSTRYKERT1AXIAL-83401
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-a9700bb7bd99> in <module>
#      36             if scan_directory[-5:] in segmented_ids:
#      37                 folder_containing_scans = scan_directory
# ---> 38                 array_of_patient_scans = imageArray(path_to_visit, folder_containing_scans)
#      39                 data_array.append(array_of_patient_scans)
#      40         pickle.dump(data_array, pickleFile)
#
# <ipython-input-16-1874d077e026> in imageArray(path_to_visit, scans_folder)
#      68         ds = pydicom.dcmread(path_of_scans+"/"+imagesDict[image])
#      69         print(len(image_array), image, imagesDict[image], ds.pixel_array.shape, path_of_scans)
# ---> 70         image_array[image-1] = ds.pixel_array
#      71
#      72     return image_array
#
# IndexError: index 20 is out of bounds for axis 0 with size 20

# %%
# Completed so far, pickle for gathering all designated original data scans for every segmentation
# scan has been completed. Testing for results. Anomalies detected with multiple
# with extra number of scans
# Needed for completing the training of the task, adding the segmentation array with every patient's array

# %%
result_files = os.listdir(result_directory_path)
file = 'TCGA-02-0006.pickle'
patient = open("%s" % (result_directory_path+file), "rb")
patient_data = pickle.load(patient)
# for i in patient_data:
for arrays in patient_data:
    plt.imshow(np.squeeze(arrays[:,:,7]), 'gray')
#     plt.savefig("%s.png" %(imgName), dpi=300, bbox_inches = 'tight', nbins=0, pad_inches=0)
#     plt.show()

# %%
segmented_ids = []
    for dcm in patient_seg_scans:
        segmented_ids.append(dcm[-9:-4])
    needed_scans = []
    for name in files:
        print(name)
        if name[-9:-4] in segmented_ids:
            needed_scans.append(name)
    print (needed_scans)
    
    
    #                 path_for_scans = original_directory_path+patient_id+"/"+visit_date+"/"+folder_containing_scans

#                 images = os.listdir(path_for_scans)

#                 original_scans = np.zeros((256,256,len(images)))
                
#                 ordered_dict_of_filenames = dicomSort(path_for_scans, images)
#                 for image in sorted(ordered_dict_of_filenames.keys()):
#                     ds = pydicom.dcmread(path_for_scans+"/"+ordered_dict_of_filenames[image]).pixel_array
#                     try:
#                         original_scans[:,:,image-1] = ds
#                     except:
#                         if patient_id not in faulty_patient_data:
#                             faulty_patient_data.append(patient_id)
#                         print("Error for:", patient_id+"/"+visit_date+"/"+scan_directory+"/"+ordered_dict_of_filenames[image]+"__"+str(ds.shape))
